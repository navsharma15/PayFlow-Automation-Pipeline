# %%
# !python -m pip install pyodbc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyodbc in C:\Users\navdh\AppData\Roaming\Python\Python314\site-packages (5.3.0)

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6E90-4D20
#
#  Directory of C:\Users\navdh\Desktop\PhonePe-Automation-Project\automation
#
# 21-07-2026  14:20    <DIR>          .
# 21-07-2026  13:40    <DIR>          ..
# 21-07-2026  14:20    <DIR>          .ipynb_checkpoints
# 21-07-2026  13:11             2,244 02_generate_daily_data.py
# 21-07-2026  13:13               728 03_append_data.py
# 21-07-2026  13:13             5,110 04_clean_data.py
# 21-07-2026  13:42             2,301 05_load_sql.py
# 21-07-2026  13:46                 0 main.py
# 21-07-2026  14:20               337 Untitled.ipynb
#                6 File(s)         10,720 bytes
#                3 Dir(s)  71,328,739,328 bytes free

# %%
# !python 02_generate_daily_data.py
# Out:
# ['Recharge_Bills']
# ['FASTag Recharge', 'DTH', 'Cable TV', 'Mobile Recharge', 'FASTag Recharge ', 'Mobile Recharge ', 'DTH ', 'Cable TV ', 'nan ']
# ['Successful', 'Failed']
# ['Successful', 'Insufficient amount', 'Wrong PIN', 'Server error']
# 50 Daily Transactions Generated Successfully

# %%
# !python 03_append_data.py

# %%
# !python 04_clean_data.py
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction ID  2038 non-null   str
#  1   Amount          2038 non-null   float64
#  2   User ID         2038 non-null   str
#  3   Service         2038 non-null   str
#  4   Service Type    2040 non-null   str
#  5   Payment_Status  2038 non-null   str
#  6   Reason          2038 non-null   str
#  7   Date            2038 non-null   str
# dtypes: float64(1), str(7)
# memory usage: 131.4 KB
# Transaction ID
# <StringArray>
# [ 'RCG_0C338474B366',  'RCG_6B3B86B07A76',  'RCG_767822392A0E',
#   'RCG_527E6AC74B11',  'RCG_6B50A8C694E1',  'RCG_E63DCBDBB8C9',
#   'RCG_DD16B3117FB9',  'RCG_654D31ECCDC2',  'RCG_6C53A7808151',
#   'RCG_92AE572161FA',
#  ...
#  'RCG_JMOODWA21F0G8', 'RCG_NAPDSELUP020L', 'RCG_B8JXAPC7P3YGM',
#  'RCG_NE78S75DCXO5C', 'RCG_WFRGBYK1YMXH6', 'RCG_408JTREE6EHCX',
#  'RCG_U8P7A0DAV9AQE', 'RCG_5VGQEK1RLLC47', 'RCG_CHVDSADTO9L9U',
#  'RCG_NYKTGLNZIYIQL']
# Length: 1996, dtype: str
# ----------------------------------------
# Amount
# [ 926.59 1211.64  746.27 ... 1127.02  962.25 1446.1 ]
# ----------------------------------------
# User ID
# <StringArray>
# ['PP0021371', 'PP0002388', 'PP1101831', 'PP0033099', 'PP1059869', 'PP1093720',
#  'PP1067328', 'PP0041770', 'PP0017979', 'PP1085390',
#  ...
#  'PP1305770', 'PP1773627', 'PP8350965', 'PP7929419', 'PP3926110', 'PP7631573',
#  'PP4792929', 'PP5759364', 'PP4201913', 'PP5951380']
# Length: 1978, dtype: str
# ----------------------------------------
# Service
# <StringArray>
# ['Recharge_Bills', nan]
# Length: 2, dtype: str
# ----------------------------------------
# Service Type
# <StringArray>
# [ 'FASTag Recharge',              'DTH',         'Cable TV',
#   'Mobile Recharge',                nan, 'FASTag Recharge ',
#  'Mobile Recharge ',             'DTH ',        'Cable TV ',
#              'nan ']
# Length: 10, dtype: str
# ----------------------------------------
# Payment_Status
# <StringArray>
# ['Successful', 'Failed', nan, 'Success']
# Length: 4, dtype: str
# ----------------------------------------
# Reason
# <StringArray>
# [          'Successful',                    nan,  'Insufficient amount',
#             'Wrong PIN',         'Server error',              'Success',
#  'Insufficient Balance',         'Server Error']
# Length: 8, dtype: str
# ----------------------------------------
# Date
# <StringArray>
# ['09-06-2024', '04-08-2024', '19-02-2024', '22-12-2024', '07-09-2024',
#  '25-07-2024', '06-08-2024', '23-04-2024', '25-06-2024', '20-11-2024',
#  ...
#  '2024/03/11', '2024/03/14', '2024/07/14', '2024/12/28', '21-06-2024',
#  '2024/01/28', '2024/12/04', '2024/09/14', '2024/06/04', '19-07-2026']
# Length: 420, dtype: str
# ----------------------------------------

# %%
# !python 05_load_sql.py
# Out:
# pyodbc installed
# ['SQL Server', 'ODBC Driver 17 for SQL Server', 'ODBC Driver 18 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']
# Connected Successfully
# Database Created Successfully
# Connected to PhonePeDB
# Table Created Successfully

# %%
print(os.getcwd())
print(os.path.abspath("../logging"))
# Out:
# C:\Users\navdh\Desktop\PhonePe-Automation-Project\automation
# C:\Users\navdh\Desktop\PhonePe-Automation-Project\logging

# %%
import subprocess
import logging


# -----------------------------
# Logging Configuration
# -----------------------------

logging.basicConfig(
    filename="../logging/automation.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    force=True
)


# -----------------------------
# Automation Pipeline
# -----------------------------

logging.info("========== Automation Started ==========")

print("Automation Started")


try:

    # Step 1: Generate Data
    subprocess.run(
        ["python", "02_generate_daily_data.py"],
        check=True
    )

    logging.info("Data Generation Completed")
    print("Data Generation Completed")


    # Step 2: Append Data
    subprocess.run(
        ["python", "03_append_data.py"],
        check=True
    )

    logging.info("Data Append Completed")
    print("Data Append Completed")


    # Step 3: Clean Data
    subprocess.run(
        ["python", "04_clean_data.py"],
        check=True
    )

    logging.info("Data Cleaning Completed")
    print("Data Cleaning Completed")


    # Step 4: Load SQL
    subprocess.run(
        ["python", "05_load_sql.py"],
        check=True
    )

    logging.info("SQL Loading Completed")
    print("SQL Loading Completed")


    # Success

    logging.info("Automation Completed Successfully")
    logging.info("======================================")


    print("Automation Completed Successfully")


except Exception as e:

    logging.error(f"Automation Failed: {e}")

    print("Automation Failed")
    print(e)
# Out:
# Automation Started
# Data Generation Completed
# Data Append Completed
# Data Cleaning Completed
# SQL Loading Completed
# Automation Completed Successfully

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\navdh\\Desktop\\PhonePe-Automation-Project\\automation'

# %%
# !python main.py
# Out:
# ['Recharge_Bills']
# ['FASTag Recharge', 'DTH', 'Cable TV', 'Mobile Recharge', 'FASTag Recharge ', 'Mobile Recharge ', 'DTH ', 'Cable TV ', 'nan ']
# ['Successful', 'Failed']
# ['Successful', 'Insufficient amount', 'Wrong PIN', 'Server error']
# 50 Daily Transactions Generated Successfully
# <class 'pandas.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction ID  2038 non-null   str
#  1   Amount          2038 non-null   float64
#  2   User ID         2038 non-null   str
#  3   Service         2038 non-null   str
#  4   Service Type    2040 non-null   str
#  5   Payment_Status  2038 non-null   str
#  6   Reason          2038 non-null   str
#  7   Date            2038 non-null   str
# dtypes: float64(1), str(7)
# memory usage: 131.4 KB
# Transaction ID
# <StringArray>
# [ 'RCG_0C338474B366',  'RCG_6B3B86B07A76',  'RCG_767822392A0E',
#   'RCG_527E6AC74B11',  'RCG_6B50A8C694E1',  'RCG_E63DCBDBB8C9',
#   'RCG_DD16B3117FB9',  'RCG_654D31ECCDC2',  'RCG_6C53A7808151',
#   'RCG_92AE572161FA',
#  ...
#  'RCG_JMOODWA21F0G8', 'RCG_NAPDSELUP020L', 'RCG_B8JXAPC7P3YGM',
#  'RCG_NE78S75DCXO5C', 'RCG_WFRGBYK1YMXH6', 'RCG_408JTREE6EHCX',
#  'RCG_U8P7A0DAV9AQE', 'RCG_5VGQEK1RLLC47', 'RCG_CHVDSADTO9L9U',
#  'RCG_NYKTGLNZIYIQL']
# Length: 1996, dtype: str
# ----------------------------------------
# Amount
# [ 926.59 1211.64  746.27 ... 1127.02  962.25 1446.1 ]
# ----------------------------------------
# User ID
# <StringArray>
# ['PP0021371', 'PP0002388', 'PP1101831', 'PP0033099', 'PP1059869', 'PP1093720',
#  'PP1067328', 'PP0041770', 'PP0017979', 'PP1085390',
#  ...
#  'PP1305770', 'PP1773627', 'PP8350965', 'PP7929419', 'PP3926110', 'PP7631573',
#  'PP4792929', 'PP5759364', 'PP4201913', 'PP5951380']
# Length: 1978, dtype: str
# ----------------------------------------
# Service
# <StringArray>
# ['Recharge_Bills', nan]
# Length: 2, dtype: str
# ----------------------------------------
# Service Type
# <StringArray>
# [ 'FASTag Recharge',              'DTH',         'Cable TV',
#   'Mobile Recharge',                nan, 'FASTag Recharge ',
#  'Mobile Recharge ',             'DTH ',        'Cable TV ',
#              'nan ']
# Length: 10, dtype: str
# ----------------------------------------
# Payment_Status
# <StringArray>
# ['Successful', 'Failed', nan, 'Success']
# Length: 4, dtype: str
# ----------------------------------------
# Reason
# <StringArray>
# [          'Successful',                    nan,  'Insufficient amount',
#             'Wrong PIN',         'Server error',              'Success',
#  'Insufficient Balance',         'Server Error']
# Length: 8, dtype: str
# ----------------------------------------
# Date
# <StringArray>
# ['09-06-2024', '04-08-2024', '19-02-2024', '22-12-2024', '07-09-2024',
#  '25-07-2024', '06-08-2024', '23-04-2024', '25-06-2024', '20-11-2024',
#  ...
#  '2024/03/11', '2024/03/14', '2024/07/14', '2024/12/28', '21-06-2024',
#  '2024/01/28', '2024/12/04', '2024/09/14', '2024/06/04', '19-07-2026']
# Length: 420, dtype: str
# ----------------------------------------
# pyodbc installed
# ['SQL Server', 'ODBC Driver 17 for SQL Server', 'ODBC Driver 18 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']
# Connected Successfully
# Database Created Successfully
# Connected to PhonePeDB
# Table Created Successfully
# Automation Started
# Data Generation Completed
# Data Append Completed
# Data Cleaning Completed
# SQL Loading Completed
# Automation Completed Successfully
